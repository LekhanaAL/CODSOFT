# %%
import pandas as pd

def convert_train_txt_to_csv(input_file, output_file):
    data = []
    with open(input_file, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split(' ::: ')
            if len(parts) == 4:  # Ensure there are exactly 4 columns
                data.append(parts)
            else:
                print(f"Skipping line due to incorrect format: {line.strip()}")
    
    df = pd.DataFrame(data, columns=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
    df.to_csv(output_file, index=False)

def convert_test_txt_to_csv(input_file, output_file):
    data = []
    with open(input_file, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split(' ::: ')
            if len(parts) == 3:  # Ensure there are exactly 3 columns
                data.append(parts)
            else:
                print(f"Skipping line due to incorrect format: {line.strip()}")
    
    df = pd.DataFrame(data, columns=['ID', 'TITLE', 'DESCRIPTION'])
    df.to_csv(output_file, index=False)

def convert_solution_txt_to_csv(input_file, output_file):
    data = []
    with open(input_file, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split(' ::: ')
            if len(parts) == 4:  # Ensure there are exactly 4 columns
                data.append(parts)
            else:
                print(f"Skipping line due to incorrect format: {line.strip()}")
    
    df = pd.DataFrame(data, columns=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
    df.to_csv(output_file, index=False)

# Convert train.txt to train.csv
convert_train_txt_to_csv('train.txt', 'train.csv')

# Convert test.txt to test.csv
convert_test_txt_to_csv('test.txt', 'test.csv')

# Convert solution.txt to solution.csv
convert_solution_txt_to_csv('solution.txt', 'solution.csv')

# %%
import pandas as pd

def convert_train_txt_to_csv(input_file, output_file):
    data = []
    with open(input_file, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split(' ::: ')
            if len(parts) == 4:  # Expecting 4 columns
                data.append(parts)
            else:
                print(f"Skipping line due to incorrect format: {line.strip()}")
    
    # Create DataFrame with specific column names
    df = pd.DataFrame(data, columns=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
    df.to_csv(output_file, index=False)

def convert_test_txt_to_csv(input_file, output_file):
    data = []
    with open(input_file, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split(' ::: ')
            if len(parts) == 3:  # Expecting 3 columns
                data.append(parts)
            else:
                print(f"Skipping line due to incorrect format: {line.strip()}")
    
    # Create DataFrame with specific column names
    df = pd.DataFrame(data, columns=['ID', 'TITLE', 'DESCRIPTION'])
    df.to_csv(output_file, index=False)

def convert_solution_txt_to_csv(input_file, output_file):
    data = []
    with open(input_file, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split(' ::: ')
            if len(parts) == 4:  # Expecting 4 columns
                data.append(parts)
            else:
                print(f"Skipping line due to incorrect format: {line.strip()}")
    
    # Create DataFrame with specific column names
    df = pd.DataFrame(data, columns=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
    df.to_csv(output_file, index=False)

# Convert train.txt to train.csv
convert_train_txt_to_csv('train.txt', 'train.csv')

# Convert test.txt to test.csv
convert_test_txt_to_csv('test.txt', 'test.csv')

# Convert solution.txt to solution.csv
convert_solution_txt_to_csv('solution.txt', 'solution.csv')
